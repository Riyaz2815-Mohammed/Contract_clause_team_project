# %%
import os
from dotenv import load_dotenv
print(load_dotenv())
# Out:
# Running cells with '.venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'e:/contract-deviation-detection/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
print("I love Python!")
# Out:
# Running cells with '.venv (Python 3.13.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'e:/contract-deviation-detection/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'
